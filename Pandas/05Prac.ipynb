# %% [markdown]
# # Practice 5

# %%
import pandas as pd

# %% [markdown]
# ## <b>data transformation</b>

# %% [markdown]
# ##### Loading data set

# %%
df = pd.read_csv('Data_set/MOCK_DATA.csv')

# %% [markdown]
# #### to rename a particular column

# %%
df = df.rename(columns={"id" : "number"})

# %% [markdown]
# ##### to convert the data type of the data in any column

# %% [markdown]
# ###### you can convert it into any data type

# %%
df["column_name"] = df["column_name"].astype("float")

# %% [markdown]
# ##### this converts a the data of a certain column into date and time format

# %%
df["number"] = pd.to_datetime(df["number"])

# %% [markdown]
# ##### this allows u to create a new column with data manipulated ny your wish like mul, add, or any operation to a existing column

# %%
df["new_column"] = df["existing_column"] * 2

# %% [markdown]
# ## <b>combining and merging dataframes</b>

# %% [markdown]
# #### concatenation

# %% [markdown]
# ###### this concat the dataframes along rows

# %%
combined_rows = pd.concat([df1, df2], axis=0)

# %% [markdown]
# ###### this concat the dataframes along columns

# %%
combined_column = pd.concat([df1, df2], axis=1)

# %% [markdown]
# ##### to merge two data set

# %% [markdown]
# ###### with this method we can merge two data set with respect to a common column in both the data set

# %%
merge_set = pd.merge(df1, df2, on="common_column" )

# %%
merged = pd.merge(df1, df2, how="left", on="common_column")
merged = pd.merge(df1, df2, how="inner", on="common_column")

# %% [markdown]
# ##### joining data frames

# %%
join = df1.join(df2, how="inner")
