# %% [markdown]
# # Practice 3

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #### Bar Graph

# %% [markdown]
# <p>Writing the categories</p>

# %%
categories = ["A", "B", "C"]

# %% [markdown]
# <p>Data</p>

# %%
data = [28, 24, 38]

# %% [markdown]
# #### Plotting data in the graph

# %%
plt.bar(categories, data, color="pink")
# Out:
# <BarContainer object of 3 artists>
