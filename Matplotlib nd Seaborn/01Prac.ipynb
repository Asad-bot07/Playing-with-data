# %% [markdown]
# # Practice 1

# %% [markdown]
# #### Importing matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #### Matplotlib is a python library for creating static and interactive, animated graph to plot our data for data visualization

# %% [markdown]
# #### Basic coords

# %%
x = [1, 2, 3, 4, 5, 6, 7, 8, 9]
y = [90, 70, 75, 43, 39, 24, 16, 3, 0]

# %% [markdown]
# #### to plot data in the graph

# %%
plt.plot(x, y)

# %% [markdown]
# #### to visualize the plotted data

# %%
plt.show()
