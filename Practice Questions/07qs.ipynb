# %% [markdown]
# #### 7. Reshape a 1D array of size 12 into a 3×4 matrix.

# %%
import numpy as np

# %%
array = np.random.randint(1, 100, size=[1, 12])
print(array)
# Out:
# [[35 29 66 69 87 94 68  6 26 26 21 41]]

# %%
new_matrix = np.reshape(array, (3, 4))
print(new_matrix)
# Out:
# [[35 29 66 69]
#  [87 94 68  6]
#  [26 26 21 41]]
