# %% [markdown]
# #### 5. Find the shape, size, and datatype of a NumPy array.

# %%
import numpy as np

# %%
array = np.random.randint(1, 100, size=[2, 3])
print(np.shape(array))
print(np.size(array))
print(type(array))
# Out:
# (2, 3)
# 6
# <class 'numpy.ndarray'>
