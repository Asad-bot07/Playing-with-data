# %% [markdown]
# #### 4. Generate an array of 10 random integers between 1 and 100.

# %%
import numpy as np

# %%
array = np.random.randint(1, 100, size=[1, 10])
print(array)
# Out:
# [[66  4 11 26 86 36 89 94 47 83]]
