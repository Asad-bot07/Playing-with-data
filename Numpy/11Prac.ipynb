# %% [markdown]
# # Practice 11

# %%
import numpy as np

# %% [markdown]
# #### Creating a 2d array and a vector

# %%
matrix = np.array([[1, 2, 3], [4, 5, 6]])
print(matrix)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
vector = np.array([1,4,8])
print(vector)
# Out:
# [1 4 8]

# %% [markdown]
# #### Addition

# %%
print(matrix + vector)
# Out:
# [[ 2  6 11]
#  [ 5  9 14]]

# %% [markdown]
# #### Multiplication

# %%
print(matrix * vector)
# Out:
# [[ 1  8 24]
#  [ 4 20 48]]
